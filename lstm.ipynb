# %%
# Import the package
import pandas as pd
import numpy as np
import fastf1 as ff1

# %%
features = ['Driver', 'DriverNumber', 'LapTime', 'FreshTyre','Position']
drivers = ['HAM', 'HEI', 'ROS', 'ALO', 'KOV', 'NAK', 'BOU', 'RAI', 'KUB',
       'GLO', 'SAT', 'PIQ', 'MAS', 'COU', 'TRU', 'SUT', 'WEB', 'BUT',
       'DAV', 'VET', 'FIS', 'BAR', 'SCH', 'LIU', 'WUR', 'SPE', 'ALB',
       'WIN', 'YAM', 'MSC', 'MON', 'KLI', 'TMO', 'IDE', 'VIL', 'FMO',
       'DLR', 'DOO', 'KAR', 'FRI', 'ZON', 'PIZ', 'BUE', 'BAD',
       'MAG', 'ALG', 'GRO', 'KOB', 'BIA', 'GAS', 'HUL', 'PET', 'DIG',
       'SEN', 'CHA', 'MAL', 'DIR', 'PER', 'DAM', 'RIC', 'VER', 'PIC',
       'CHI', 'GUT', 'BOT', 'VDG', 'KVY', 'LOT', 'ERI', 'STE', 'NAS',
       'SAI', 'MER', 'RSS', 'PAL', 'WEH', 'HAR', 'VAN', 'OCO', 'STR',
       'GIO', 'LEC', 'SIR', 'NOR', 'RUS', 'LAT', 'FIT', 'AIT', 'TSU',
       'MAZ', 'ZHO', 'DEV', 'PIA', 'SAR', 'LAW']

# %%
races=['albert_park', 'sepang', 'bahrain', 'catalunya', 'istanbul',
       'monaco', 'villeneuve', 'magny_cours', 'silverstone',
       'hockenheimring', 'hungaroring', 'valencia', 'spa', 'monza',
       'marina_bay', 'fuji', 'shanghai', 'interlagos', 'indianapolis',
       'nurburgring', 'imola', 'suzuka', 'vegas', 'yas_marina', 'galvez',
       'jerez', 'estoril', 'okayama', 'adelaide', 'kyalami', 'donington',
       'rodriguez', 'phoenix', 'ricard', 'yeongam', 'jacarepagua',
       'detroit', 'brands_hatch', 'zandvoort', 'zolder', 'dijon',
       'dallas', 'long_beach', 'las_vegas', 'jarama', 'watkins_glen',
       'anderstorp', 'mosport', 'montjuic', 'nivelles', 'charade',
       'tremblant', 'essarts', 'lemans', 'reims', 'george', 'zeltweg',
       'aintree', 'boavista', 'riverside', 'avus', 'monsanto', 'sebring',
       'ain-diab', 'pescara', 'bremgarten', 'pedralbes', 'buddh',
       'americas', 'red_bull_ring', 'sochi', 'baku', 'portimao',
       'mugello', 'jeddah', 'losail', 'miami']

years = [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2010, 2011, 2012,  2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]

# %%
df_full = pd.DataFrame()

# %%
for year in years:    
    for race in races:
        try:
            print("year:", year)
            x = ff1.get_session(year, race, 'R')
            x.load()
            print("race:", race)
            for driver in drivers:
                driver_laps = x.laps.pick_driver(driver).pick_quicklaps().reset_index()
                df3 = driver_laps[features].copy()
                df_full = pd.concat([df_full, df3], ignore_index=True)
                print("driver added:", driver)
        except Exception as e:
            print(f"An error occurred: {e}")
# Out:
# year: 2000
# core           INFO 	Loading data for European Grand Prix - Race [v3.1.5]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# logger      WARNING 	Failed to load session info data!
# core        WARNING 	Cannot load laps, telemetry, weather, and message data because the relevant API is not supported for this session.
# core           INFO 	Finished loading data for 21 drivers: ['3', '1', '2', '4', '11', '18', '16', '21', '14', '10', '8', '12', '23', '20', '22', '7', '19', '9', '17', '5', '6']
# core           INFO 	Loading data for Spanish Grand Prix - Race [v3.1.5]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# race: albert_park
# An error occurred: The data you are trying to access has not been loaded yet. See `Session.load`
# year: 2000
# logger      WARNING 	Failed to load session info data!
# ...

# %%
df_full
# Out:
#        Driver DriverNumber                LapTime  FreshTyre  Position
# 0         HAM           44 0 days 00:01:36.761000          0      15.0
# 1         HAM           44 0 days 00:01:35.486000          0      14.0
# 2         HAM           44 0 days 00:01:35.173000          0      13.0
# 3         HAM           44 0 days 00:01:34.975000          0      11.0
# 4         HAM           44 0 days 00:01:33.772000          0      10.0
# ...       ...          ...                    ...        ...       ...
# 358202    TSU           22 0 days 00:01:35.133000          0      13.0
# 358203    ZHO           24 0 days 00:01:37.487000          1      14.0
# 358204    ZHO           24 0 days 00:01:36.727000          1      14.0
# 358205    ZHO           24 0 days 00:01:35.731000          1      14.0
# 358206    ZHO           24 0 days 00:01:35.883000          1      14.0
#
# [358207 rows x 5 columns]

# %%
df_old = pd.read_csv('df_full.csv')
df_old
# Out:
#        Driver  DriverNumber                 LapTime  FreshTyre  Position
# 0         HAM            44  0 days 00:01:35.270000       True       6.0
# 1         HAM            44  0 days 00:01:35.120000       True       6.0
# 2         HAM            44  0 days 00:01:33.731000       True       4.0
# 3         HAM            44  0 days 00:01:33.955000       True       4.0
# 4         HAM            44  0 days 00:01:33.679000       True       4.0
# ...       ...           ...                     ...        ...       ...
# 207796    LAT             6  0 days 00:01:25.487000       True      12.0
# 207797    LAT             6  0 days 00:01:25.926000       True      12.0
# 207798    LAT             6  0 days 00:01:26.705000       True      12.0
# 207799    LAT             6  0 days 00:01:25.647000       True      11.0
# 207800    LAT             6  0 days 00:01:25.345000       True      11.0
#
# [207801 rows x 5 columns]

# %%
df = pd.concat([df_old, df_full], ignore_index=True)
df
# Out:
#        Driver DriverNumber                 LapTime  FreshTyre  Position
# 0         HAM           44  0 days 00:01:35.270000          1       6.0
# 1         HAM           44  0 days 00:01:35.120000          1       6.0
# 2         HAM           44  0 days 00:01:33.731000          1       4.0
# 3         HAM           44  0 days 00:01:33.955000          1       4.0
# 4         HAM           44  0 days 00:01:33.679000          1       4.0
# ...       ...          ...                     ...        ...       ...
# 566003    TSU           22  0 days 00:01:35.133000          0      13.0
# 566004    ZHO           24  0 days 00:01:37.487000          1      14.0
# 566005    ZHO           24  0 days 00:01:36.727000          1      14.0
# 566006    ZHO           24  0 days 00:01:35.731000          1      14.0
# 566007    ZHO           24  0 days 00:01:35.883000          1      14.0
#
# [566008 rows x 5 columns]

# %%
df.dtypes
# Out:
# Driver           object
# DriverNumber     object
# LapTime          object
# FreshTyre         int64
# Position        float64
# dtype: object

# %%
timedelta_str = "0 days 00:01:35.270000"

# Convert the string to a timedelta object
timedelta_obj = pd.to_timedelta(timedelta_str)
timedelta_obj.total_seconds()
# apply the above code to LapTime column
df['LapTime'] = df['LapTime'].apply(lambda x: pd.to_timedelta(x).total_seconds())

# %%
df.dtypes
# Out:
# Driver           object
# DriverNumber     object
# LapTime         float64
# FreshTyre         int64
# Position        float64
# dtype: object

# %%
df
# Out:
#        Driver DriverNumber  LapTime  FreshTyre  Position
# 0         HAM           44   95.270          1       6.0
# 1         HAM           44   95.120          1       6.0
# 2         HAM           44   93.731          1       4.0
# 3         HAM           44   93.955          1       4.0
# 4         HAM           44   93.679          1       4.0
# ...       ...          ...      ...        ...       ...
# 566003    TSU           22   95.133          0      13.0
# 566004    ZHO           24   97.487          1      14.0
# 566005    ZHO           24   96.727          1      14.0
# 566006    ZHO           24   95.731          1      14.0
# 566007    ZHO           24   95.883          1      14.0
#
# [566008 rows x 5 columns]

# %%
#convert to csv
df.to_csv('df_all.csv')

# %%
df['FreshTyre'] = df['FreshTyre'].astype(int)

# %%
df
# Out:
#        Driver DriverNumber  LapTime  FreshTyre  Position
# 0         HAM           44   95.270          1       6.0
# 1         HAM           44   95.120          1       6.0
# 2         HAM           44   93.731          1       4.0
# 3         HAM           44   93.955          1       4.0
# 4         HAM           44   93.679          1       4.0
# ...       ...          ...      ...        ...       ...
# 566003    TSU           22   95.133          0      13.0
# 566004    ZHO           24   97.487          1      14.0
# 566005    ZHO           24   96.727          1      14.0
# 566006    ZHO           24   95.731          1      14.0
# 566007    ZHO           24   95.883          1      14.0
#
# [566008 rows x 5 columns]

# %%
import seaborn as sns
sns.distplot(df['LapTime'])
# Out:
# /var/folders/lw/glss8t557pv__tkfgv16_7rm0000gn/T/ipykernel_88065/2611381658.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['LapTime'])
# <Axes: xlabel='LapTime', ylabel='Density'>

# %%
features = df[['DriverNumber', 'LapTime', 'FreshTyre']]
features
# Out:
#        DriverNumber  LapTime  FreshTyre
# 0                44   95.270          1
# 1                44   95.120          1
# 2                44   93.731          1
# 3                44   93.955          1
# 4                44   93.679          1
# ...             ...      ...        ...
# 566003           22   95.133          0
# 566004           24   97.487          1
# 566005           24   96.727          1
# 566006           24   95.731          1
# 566007           24   95.883          1
#
# [566008 rows x 3 columns]

# %%
label = df['Position']

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split


# Splitting the dataset into training and a temporary set (80% training, 20% temp)
X_train, X_temp, Y_train, Y_temp = train_test_split(features, label, test_size=0.2, shuffle=False)

# Splitting the temporary set into validation and test sets (50% validation, 50% test of the temp set)
# This results in 80% training, 10% validation, and 10% test sets of the original dataset
X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, shuffle=False)

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_val_scaled = scaler.transform(X_val)

# %%
def create_sequences(X, Y, sequence_length):
        X_seq, Y_seq = [], []
        for i in range(len(X) - sequence_length):
            X_seq.append(X[i: i + sequence_length])
            Y_seq.append(Y.iloc[i + sequence_length])
        return np.array(X_seq), np.array(Y_seq)

# %%
X_train_seq, Y_train_seq = create_sequences(X_train_scaled, Y_train, 30)
X_test_seq, Y_test_seq = create_sequences(X_test_scaled, Y_test, 30)
X_val_seq, Y_val_seq = create_sequences(X_val_scaled, Y_val, 30)

# %%
print("X_train:",X_train_seq.shape)
print("Y_train:",Y_train_seq.shape)
print("X_test:",X_test_seq.shape)
print("Y_test:",Y_test_seq.shape)
print("X_val:",X_val_seq.shape)
print("Y_val:",Y_val_seq.shape)
# Out:
# X_train: (452776, 30, 3)
# Y_train: (452776,)
# X_test: (56571, 30, 3)
# Y_test: (56571,)
# X_val: (56571, 30, 3)
# Y_val: (56571,)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.callbacks import EarlyStopping


# Initialize the LSTM model
model = Sequential()

# First LSTM layer with dropout
model.add(LSTM(units=100, return_sequences=True, input_shape=(30, 3)))
model.add(Dropout(0.3))

# Second LSTM layer with dropout
model.add(LSTM(units=100, return_sequences=True))
model.add(Dropout(0.3))

# Third LSTM layer with dropout
model.add(LSTM(units=100, return_sequences=False))
model.add(Dropout(0.3))

# Additional Dense layers before the output
model.add(Dense(units=50, activation='relu'))
model.add(Dense(units=25, activation='relu'))

# Output layer
model.add(Dense(units=1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Train the model with Early Stopping
history = model.fit(
    X_train_seq, 
    Y_train_seq, 
    epochs=30, 
    batch_size=64, 
    validation_data=(X_val_seq, Y_val_seq),
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/30
# 7075/7075 [==============================] - 479s 67ms/step - loss: 23.2031 - val_loss: 21.2551
# Epoch 2/30
# 7075/7075 [==============================] - 484s 68ms/step - loss: 17.1792 - val_loss: 16.3026
# Epoch 3/30
# 7075/7075 [==============================] - 440s 62ms/step - loss: 14.3522 - val_loss: 12.6859
# Epoch 4/30
# 7075/7075 [==============================] - 454s 64ms/step - loss: 12.8733 - val_loss: 11.5799
# Epoch 5/30
# 7075/7075 [==============================] - 421s 60ms/step - loss: 11.5846 - val_loss: 11.1382
# Epoch 6/30
# 7075/7075 [==============================] - 434s 61ms/step - loss: 10.7401 - val_loss: 9.8571
# Epoch 7/30
# 7075/7075 [==============================] - 461s 65ms/step - loss: 9.9399 - val_loss: 9.3099
# Epoch 8/30
# 7075/7075 [==============================] - 412s 58ms/step - loss: 9.3218 - val_loss: 8.8238
# Epoch 9/30
# 7075/7075 [==============================] - 394s 56ms/step - loss: 8.8854 - val_loss: 8.8072
# ...

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

# Predicting on the test set
Y_pred = model.predict(X_test_seq)

# Calculate MSE and MAE
mse = mean_squared_error(Y_test_seq, Y_pred)
mae = mean_absolute_error(Y_test_seq, Y_pred)

# Calculate RMSE
rmse = np.sqrt(mse)

print(f'Mean Squared Error: {mse}')
print(f'Mean Absolute Error: {mae}')
print(f'Root Mean Squared Error: {rmse}')
# Out:
# 1768/1768 [==============================] - 16s 9ms/step
# Mean Squared Error: 6.191089387023237
# Mean Absolute Error: 1.64618717097201
# Root Mean Squared Error: 2.488189982100088

# %%
# %pip install lime
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 2.2 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 23.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 524.7 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.3/313.3 kB 3.8 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 29.1 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.9/222.9 kB 9.7 MB/s eta 0:00:00
# ...
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283834 sha256=67182ea654ca631b9f2a7659ac0a096532e29e1d5b10b15f79643017dd6cf670
#   Stored in directory: /Users/shreyanshmac/Library/Caches/pip/wheels/85/fa/a3/9c2d44c9f3cd77cf4e533b58900b2bf4487f2a17e8ec212a3d
# Successfully built lime
# ...

# %%
import lime
import lime.lime_tabular

# %%
X_train_flattened = X_train_seq.reshape(X_train_seq.shape[0], -1)
X_train_flattened.shape
# Out:
# (452776, 90)

# %%
# X_train.dtypes
#convert everything to float
X_train = X_train.astype(float)
X_train.dtypes
# Out:
# DriverNumber    float64
# LapTime         float64
# FreshTyre       float64
# dtype: object

# %%
Y_train
# Out:
# 0         6.0
# 1         6.0
# 2         4.0
# 3         4.0
# 4         4.0
#          ...
# 452801    9.0
# 452802    9.0
# 452803    9.0
# 452804    9.0
# 452805    9.0
# Name: Position, Length: 452806, dtype: float64

# %%
explainer = LimeTabularExplainer(
    training_data=X_train_flattened,  # Reshape if needed
    mode='regression'
)
# explainer = lime.lime_tabular.LimeTabularExplainer(X_train.values, feature_names=X_train.columns.values.tolist(),
#                                                   class_names=['Position'], verbose=True, mode='regression')

# %%
# def predict_fn(data):
#     reshaped_data = data.reshape(1, 30, 3)
#     return model.predict(reshaped_data)
j = 4
exp = explainer.explain_instance(X_test.values[j], model.predict, num_features=3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/shreyanshmac/Documents/DSCI 565 DL/finalProject/new/F1PyStats/notebooks/try3.ipynb Cell 33 line 5
#       <a href='vscode-notebook-cell:/Users/shreyanshmac/Documents/DSCI%20565%20DL/finalProject/new/F1PyStats/notebooks/try3.ipynb#X50sZmlsZQ%3D%3D?line=0'>1</a> # def predict_fn(data):
#       <a href='vscode-notebook-cell:/Users/shreyanshmac/Documents/DSCI%20565%20DL/finalProject/new/F1PyStats/notebooks/try3.ipynb#X50sZmlsZQ%3D%3D?line=1'>2</a> #     reshaped_data = data.reshape(1, 30, 3)
#       <a href='vscode-notebook-cell:/Users/shreyanshmac/Documents/DSCI%20565%20DL/finalProject/new/F1PyStats/notebooks/try3.ipynb#X50sZmlsZQ%3D%3D?line=2'>3</a> #     return model.predict(reshaped_data)
# ...

# %%
predict_fn(X_test_seq[0])
# Out:
# 1/1 [==============================] - 0s 30ms/step
# array([[14.78443]], dtype=float32)

# %%
model.predict(X_test_seq.reshape(X_test_seq.shape[0], 30, 3))
# Out:
# 1768/1768 [==============================] - 16s 9ms/step
# array([[14.784428 ],
#        [14.764849 ],
#        [14.635773 ],
#        ...,
#        [13.6135025],
#        [12.248028 ],
#        [ 9.998754 ]], dtype=float32)

# %%
instance_to_explain = X_test_seq[0].reshape(1, -1) 
instance_to_explain[0]
# Out:
# array([-0.38623603,  0.27780188, -1.66968268, -0.38623603,  0.20203364,
#        -1.66968268, -0.38623603,  0.1977586 , -1.66968268, -0.38623603,
#         0.20603581, -1.66968268, -0.38623603,  0.17983983, -1.66968268,
#        -0.38623603,  0.17965791, -1.66968268, -0.38623603,  0.36894206,
#        -1.66968268, -0.38623603,  0.1862069 , -1.66968268, -0.38623603,
#         0.15164276, -1.66968268, -0.38623603,  0.19066386, -1.66968268,
#        -0.38623603,  0.22277213, -1.66968268, -0.38623603,  0.21276672,
#        -1.66968268, -0.38623603,  0.18929949, -1.66968268, -0.38623603,
#         0.32691934, -1.66968268, -0.38623603,  0.32328101, -1.66968268,
#        -0.38623603,  0.52921053, -1.66968268, -0.38623603,  0.28034871,
#        -1.66968268, -0.38623603,  0.055227  , -1.66968268, -0.38623603,
#         0.20894647, -1.66968268, -0.38623603,  0.11434987, -1.66968268,
#        -0.38623603,  0.10680034, -1.66968268, -0.38623603,  0.22941208,
# ...

# %%
predict_fn(instance_to_explain[0])
# Out:
# 1/1 [==============================] - 0s 29ms/step
# array([[14.78443]], dtype=float32)

# %%
"""
So the predict_fn should take the 1D array from the instance_to_explain and reshape it to (1, 30, 3) and then return the prediction.
"""
# Out:
# ''

# %%
# show models architecture report 
from keras.utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
# %pip install pydot
# %pip install graphviz
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 609.3 kB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_9 (LSTM)               (None, 30, 100)           41600
#
#  dropout_9 (Dropout)         (None, 30, 100)           0
#
#  lstm_10 (LSTM)              (None, 30, 100)           80400
#
#  dropout_10 (Dropout)        (None, 30, 100)           0
#
#  lstm_11 (LSTM)              (None, 100)               80400
#
#  dropout_11 (Dropout)        (None, 100)               0
#
#  dense_9 (Dense)             (None, 50)                5050
#
#  dense_10 (Dense)            (None, 25)                1275
#
#  dense_11 (Dense)            (None, 1)                 26
#
# ...
# Total params: 208751 (815.43 KB)
# Trainable params: 208751 (815.43 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
plt.figure(figsize=(10, 6))
bars = plt.barh(list(shap_values.keys()), list(shap_values.values()), color='red')

# Add the values outside the bars
for bar in bars:
    width = bar.get_width()
    plt.text(width + 0.1, bar.get_y() + bar.get_height() / 2, f'{width:.2f}', 
             va='center', ha='right' if width < 0 else 'left', color='black', fontsize=8)

# Invert y-axis to have the largest bar on top
plt.gca().invert_yaxis()

# Make the y-axis line visible
plt.gca().spines['left'].set_visible(True)

# Set the title and labels
plt.xlabel('mean(|SHAP value|)')
plt.title('Feature importance based on SHAP values')

# Adjust the limits of x-axis to fit the labels
plt.xlim(min(list(shap_values.values())) * 1.1, max(list(shap_values.values())) * 1.1)

# Show the plot
plt.show()
